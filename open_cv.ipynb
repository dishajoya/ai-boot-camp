# %%
import cv2
from google.colab.patches import cv2_imshow

image_path = '/content/download (1).jpeg'
#read the image usimg cv2.impread()
img = cv2.imread(image_path)

#check if the image was loaded successfully
if img is None:
   print(f"error:image not found at{image_path}or unable to load.")
else:
   #Disply the image using cv2_imshow
   cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=165x306>
