# %%
print("hello,world")
# Out:
# hello,world

# %%
a=2
b=3
c=a+b
("sum of the given number is",c)
# Out:
# ('sum of the given number is', 5)

# %%
j=float(input("enter first number"))
a=float(input("enter second number"))
b=j*a
print("the product of two number",b)
# Out:
# enter first number678
# enter second number78
# the product of two number 52884.0
